# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
z= np.arange(-7,7,.1)

# %%
phiz= 1.0/(1.0+ np.exp(-z))

# %%
plt.xkcd()

# %%
plt.plot(z,phiz,color='r')
plt.xlabel('z')
plt.ylabel('phiz')
# Out:
# Text(0, 0.5, 'phiz')
