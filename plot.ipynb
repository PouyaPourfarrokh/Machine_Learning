# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[2,4,6,8,10]

# %%
plt.plot(x,y,'r--p',label='y=2x')
plt.legend()
plt.title('test')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
x1=[1,2,3,4,5]
y1=[1,4,9,16,25]

# %%
plt.plot(x1,y1,'b--p', label='y=x^2')
plt.plot(x,y,'r--p',label='y=2x')
plt.legend()

# %%
plt.subplot(211)
plt.plot(x,y,'r--p',label='y=2x')
plt.legend()

plt.subplot(212)
plt.plot(x1,y1,'b--p',label='y=x^2')
plt.legend()
